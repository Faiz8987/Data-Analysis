# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
mcu=pd.read_csv("C:\\Users\\lenovo\\Downloads\\charcters_stats.csv")

# %%
mcu.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
mcu.shape
# Out:
# (611, 9)

# %%
mcu['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
good=mcu[mcu['Alignment']=='good']

# %%
good
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
good.sort_values(by=['Speed'],ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
# ..              ...       ...           ...       ...    ...         ...
# 280       Hellstorm      good             1         1      1           1
# 445         Quantum      good             1         1      1           1
# 277   Hawkwoman III      good             1         1      1           1
# 276    Hawkwoman II      good             1         1      1           1
# 405           Namor      good             1         1      1           1
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# ...

# %%
good.sort_values(by=['Power'],ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609         Zatanna      good            75        10     23          28
# 546            Thor      good            69       100     92         100
# 511           Spawn      good            75        60     50          90
# 69    Beta Ray Bill      good            63        80     35          95
# 70         Beyonder      good            88       100     23         100
# ..              ...       ...           ...       ...    ...         ...
# 127       Bumbleboy      good             1         1      1           1
# 124  Brother Voodoo      good             1         1      1           1
# 415     Nite Owl II      good             1         1      1           1
# 120         Box III      good             1         1      1           1
# 100     Blaquesmith      good             1         1      1           1
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# ...

# %%
good.sort_values(by=['Intelligence'],ascending=False)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 306          Jean Grey      good           100        80     67         100
# 123         Brainiac 5      good           100        10     23          28
# 433            Phoenix      good           100        80     67         100
# 417               Nova      good           100        85     67         101
# ..                 ...       ...           ...       ...    ...         ...
# 55           Batgirl I      good             1         1      1           1
# 434        Plastic Lad      good             1         1      1           1
# 439          Power Man      good             1         1      1           1
# 234  Franklin Richards      good             1         1      1           1
# 114               Bolt      good             1         1      1           1
#
#      Power  Combat  Total
# 361    100      85    581
# ...

# %%
max_power=good[good['Power']==100]

# %%
max_power.head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %%
max_power.shape
# Out:
# (33, 9)

# %%
max_power
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# ...

# %%
aa=good.sort_values(by=['Total'],ascending=False)

# %%
bad=mcu[mcu['Alignment']=='bad']

# %%
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
sns.barplot(x=aa['Name'][0:5],y=aa['Total'][0:5],palette='Set2')
plt.show()

# %%
max_power.head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %%
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
ss=bad.sort_values(by=['Total'],ascending=False)

# %%
ss.head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
sns.barplot(x=ss['Name'][0:3],y=ss['Total'][0:3],color='red')
plt.show()

# %%
plt.bar(bad['Name'][0:3],bad['Total'][0:3],color=['black','grey','orange'])
plt.show()

# %%
plt.pie(ss['Total'][0:5],labels=ss['Name'][0:5],colors=['red','green','gold','silver','grey'],autopct='%0.1f%%')
plt.show()

# %%
plt.pie(aa['Total'][0:5],labels=aa['Name'][0:5],autopct='%0.1f%%')
plt.show()

# %%
ss.sort_values(by=['Intelligence'],ascending=False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 194      Doctor Doom       bad           100        32     20         100
# 29        Apocalypse       bad           100       100     33         100
# 315            Joker       bad           100        10     12          56
# 555         Tinkerer       bad           100        10     23          14
# ..               ...       ...           ...       ...    ...         ...
# 79       Bird-Man II       bad             1         1      1           1
# 21            Angela       bad             1         1      1           1
# 515   Spider-Carnage       bad             1         1      1           1
# 83      Black Abbott       bad             1         1      1           1
# 254      Goliath III       bad             1         1      1           1
#
#      Power  Combat  Total
# 386    100      28    277
# ...

# %%
ss
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
# ..              ...       ...           ...       ...    ...         ...
# 103        Blizzard       bad             1         1      1           1
# 349   Luke Campbell       bad             1         1      1           1
# 181        Darkside       bad             1         1      1           1
# 390          Moloch       bad             1         1      1           1
# 254     Goliath III       bad             1         1      1           1
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# ...

# %%
ss[ss['Name']=='Thanos']
# Out:
#        Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 542  Thanos       bad            88       100     17         100    100
#
#      Combat  Total
# 542      80    485

# %%
ss.sort_values(by=["Speed"],ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 16            Amazo       bad            75       100    100         100
# 610            Zoom       bad            50        10    100          28
# 11       Air-Walker       bad            50        85    100          85
# 242     General Zod       bad            94       100     96         100
# ..              ...       ...           ...       ...    ...         ...
# 67           Beetle       bad             1         1      1           1
# 79      Bird-Man II       bad             1         1      1           1
# 515  Spider-Carnage       bad             1         1      1           1
# 83     Black Abbott       bad             1         1      1           1
# 254     Goliath III       bad             1         1      1           1
#
#      Power  Combat  Total
# 535    100      85    579
# 16     100     100    575
# ...

# %%
aa.head()
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %%
sns.displot(aa['Speed'],color='brown')
plt.show()

# %%
sns.displot(bad['Combat'],color='black')
sns.set(style='whitegrid')
plt.title('bad combat')
plt.show()
