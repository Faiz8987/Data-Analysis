# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
aa=pd.read_csv("C:\\Users\\lenovo\\Downloads\\players_20.csv")

# %%
for l in aa.columns:
    print(l)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
aa.shape
# Out:
# (18278, 104)

# %%
18278*104
# Out:
# 1900912

# %%
aa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
aa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
aa['nationality'].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
plt.bar(aa['nationality'].value_counts().keys()[0:5],aa['nationality'].value_counts()[0:5],color=['red','black','grey','brown','gold'])
plt.figure(figsize=(5,5))
plt.show()

# %%
aa
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
player_salary=aa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary
# Out:
#               short_name  wage_eur
# 0               L. Messi    565000
# 4              E. Hazard    470000
# 1      Cristiano Ronaldo    405000
# 5           K. De Bruyne    370000
# 22          A. Griezmann    370000
# ...                  ...       ...
# 565         J. Serendero         0
# 1868           M. Mevlja         0
# 14723       R. Fernández         0
# 16356          H. Ivanov         0
# 3053       F. Kudryashov         0
#
# [18278 rows x 2 columns]

# %%
plt.figure(figsize=(8,6))
plt.bar(player_salary['short_name'][0:4],player_salary['wage_eur'][0:4],color=['purple','pink','blue','red','brown'])

plt.show()

# %%
argentina=aa[aa['nationality']=='Argentina']

# %%
argentina.head()
# Out:
#     sofifa_id                                         player_url   short_name  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...     L. Messi
# 17     153079  https://sofifa.com/player/153079/sergio-aguero...    S. Agüero
# 23     211110  https://sofifa.com/player/211110/paulo-dybala/...    P. Dybala
# 66     183898  https://sofifa.com/player/183898/angel-di-mari...  A. Di María
# 93     201399  https://sofifa.com/player/201399/mauro-icardi/...    M. Icardi
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 0      Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
# 17  Sergio Leonel Agüero del Castillo   31  1988-06-02        173         70
# 23        Paulo Bruno Exequiel Dybala   25  1993-11-15        177         75
# 66    Ángel Fabián Di María Hernández   31  1988-02-14        180         69
# 93        Mauro Emanuel Icardi Rivero   26  1993-02-19        181         75
#
# ...

# %%
argentina.sort_values(['age'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 11832     142998  https://sofifa.com/player/142998/cristian-muno...
# 3706      156483  https://sofifa.com/player/156483/cristian-lucc...
# 10702     162952  https://sofifa.com/player/162952/mauricio-cara...
# 8359      142818  https://sofifa.com/player/142818/fabian-cubero...
# 4690      216692  https://sofifa.com/player/216692/sebastian-tor...
#
#          short_name                        long_name  age         dob  \
# 11832      C. Muñoz  Cristian Fernando Muñoz Hoffman   42  1977-07-01
# 3706   C. Lucchetti         Cristian David Lucchetti   41  1978-06-26
# 10702    M. Caranta           Mauricio Ariel Caranta   40  1978-07-31
# 8359      F. Cubero            Fabián Alberto Cubero   40  1978-12-21
# 4690     S. Torrico        Sebastián Alberto Torrico   39  1980-02-22
#
#        height_cm  weight_kg nationality                          club  ...  \
# ...

# %%
aa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
argentina.sort_values(by=['height_cm'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 6542      223071  https://sofifa.com/player/223071/fernando-pell...
# 6067      222889  https://sofifa.com/player/222889/lucas-acevedo...
# 1786      205186  https://sofifa.com/player/205186/paulo-gazzani...
# 1141      152993  https://sofifa.com/player/152993/renato-civell...
# 519       179847  https://sofifa.com/player/179847/federico-fazi...
# ...          ...                                                ...
# 1923      170719  https://sofifa.com/player/170719/diego-buonano...
# 4552      190629  https://sofifa.com/player/190629/daniel-villal...
# 15878     241046  https://sofifa.com/player/241046/jonas-romero/...
# 1496      183895  https://sofifa.com/player/183895/maxi-moralez/...
# 4829      237994  https://sofifa.com/player/237994/nahuel-barrio...
#
#           short_name                        long_name  age         dob  \
# 6542   F. Pellegrino              Fernando Pellegrino   33  1986-03-31
# ...

# %%
argentina.sort_values(by=['weight_kg'],ascending=True)
# Out:
#        sofifa_id                                         player_url  \
# 1496      183895  https://sofifa.com/player/183895/maxi-moralez/...
# 1923      170719  https://sofifa.com/player/170719/diego-buonano...
# 2637      232517  https://sofifa.com/player/232517/nicolas-silva...
# 4829      237994  https://sofifa.com/player/237994/nahuel-barrio...
# 15878     241046  https://sofifa.com/player/241046/jonas-romero/...
# ...          ...                                                ...
# 1243      226378  https://sofifa.com/player/226378/ramon-abila/2...
# 682       176919  https://sofifa.com/player/176919/nahuel-guzman...
# 2174      227275  https://sofifa.com/player/227275/agustin-rossi...
# 6067      222889  https://sofifa.com/player/222889/lucas-acevedo...
# 9006      235925  https://sofifa.com/player/235925/gaston-gomez/...
#
#           short_name                     long_name  age         dob  \
# 1496      M. Moralez     Maximiliano Nicol Moralez   32  1987-02-27
# ...

# %%
argentina[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      short_name  wage_eur
# 0      L. Messi    565000
# 17    S. Agüero    300000
# 23    P. Dybala    215000
# 98   G. Higuaín    175000
# 66  A. Di María    150000

# %%
argentina['short_name'].value_counts()
# Out:
# J. Correa        3
# J. Rodríguez     3
# D. Rodríguez     2
# C. Álvarez       2
# R. Funes Mori    2
#                 ..
# C. Menéndez      1
# J. Schunke       1
# R. Delgado       1
# E. Cerutti       1
# N. Forastiero    1
# Name: short_name, Length: 851, dtype: int64

# %%
aa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
shoot=aa[['short_name','shooting']]

# %%
shoot.head()
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0

# %%
shoot.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
aa.sort_values(by=['attacking_finishing'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 12        202126  https://sofifa.com/player/202126/harry-kane/20...
# 17        153079  https://sofifa.com/player/153079/sergio-aguero...
# 19        176580  https://sofifa.com/player/176580/luis-suarez/2...
# ...          ...                                                ...
# 16422     251332  https://sofifa.com/player/251332/ryan-bouallak...
# 12165     242879  https://sofifa.com/player/242879/maarten-vande...
# 16753     247020  https://sofifa.com/player/247020/wilfried-bedf...
# 16215     238628  https://sofifa.com/player/238628/jan-albrecht/...
# 8110      201847  https://sofifa.com/player/201847/louis-bostyn/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
attack=aa[['short_name','attacking_finishing']]

# %%
attack.sort_values(by=['attacking_finishing'],ascending=False)
# Out:
#               short_name  attacking_finishing
# 0               L. Messi                   95
# 1      Cristiano Ronaldo                   94
# 12               H. Kane                   94
# 17             S. Agüero                   93
# 19             L. Suárez                   91
# ...                  ...                  ...
# 16422        R. Bouallak                    4
# 12165     M. Vandevoordt                    3
# 16753         W. Bedfian                    3
# 16215        J. Albrecht                    2
# 8110           L. Bostyn                    2
#
# [18278 rows x 2 columns]

# %%
defending=aa[['short_name','defending','nationality','club']]

# %%
defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
real=aa[aa['club']=='Real Madrid']

# %%
aa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
real.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 46    K. Benzema        Karim Benzema   31  1987-12-19        185         81
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# ...

# %%
real.sort_values(by=['age'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 8       177003  https://sofifa.com/player/177003/luka-modric/2...
# 53      193041  https://sofifa.com/player/193041/keylor-navas/...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 101     176676  https://sofifa.com/player/176676/marcelo-vieir...
#
#        short_name                       long_name  age         dob  height_cm  \
# 18   Sergio Ramos             Sergio Ramos García   33  1986-03-30        184
# 8       L. Modrić                     Luka Modrić   33  1985-09-09        172
# 53       K. Navas                    Keylor Navas   32  1986-12-15        185
# 46     K. Benzema                   Karim Benzema   31  1987-12-19        185
# 101       Marcelo  Marcelo Vieira da Silva Júnior   31  1988-05-12        174
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
real.sort_values(by=['attacking_finishing'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
#
#        short_name                    long_name  age         dob  height_cm  \
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
real['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64

# %%
real.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...
